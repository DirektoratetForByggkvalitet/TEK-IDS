# %%
import ifcopenshell
from ifctester import reporter
from ifctester import ids

# %% [markdown]
# # Lage IDS Trapp
#
# [IDS docutmentation](https://github.com/buildingSMART/IDS/blob/master/Documentation) in buildingSMART github repo.
#
#
# ## Lage IDS
# Start by folling the [metadata guidelines found here.](https://github.com/buildingSMART/IDS/blob/master/Documentation/ids-metadata.md)
#
# ## Trappe IDS
#
# Trappeforskriften har en del valg i seg (som vises i flyt diagrammet under), som gjør at det ikke er rett frem å representere i én IDS.
#
# ![Trappeveiviser prosess](../img/trappevalg.png)
#
# IDS har i utgangspunktet ikke en kontrollflyt i seg, så man må klare seg med å definere applicability og kardinaliteter per spesifikasjon.
#
# Strategien blir folgende:
#
# 1) Spesifisere krav til at alle enumerasjoner finnes der de skal (eks. trappetype). En må være valgt.
# 2) Lage en spesifikasjoner for hver "slutt tilstand" i veileder, hvor hver spesifikasjon teser på flere faceter der valgende fra hver enumerasjon blir satt sammen i kombinasjon.
#
# Dette vil kunne sørge for at sjekkene for §12-14 kan være i en IDS fil og gi et fornuftig test resultat.

# %% [markdown]
# ## §12-14. Trapp
# Vi lager en prototype på IDS for å sjekke opp mot [§12-14. Trapp](hhttps://www.dibk.no/regelverk/byggteknisk-forskrift-tek17/12/iii/12-14).
#
# Ambisjonen er å kunne lage en IDS som sikrer at modeller kan valideres mot IDSen for å ha tilsterekkelig informasjon for å kunne tilfredstille de preaksepterte ytelsene.
#
# Med IDS kan vi lage maskinlesbare krav til at modellene lar seg sjekke, i tillegg til å sjekke på faktiske verdier i modellen. Dette gjør at de fleste kravene kan sjekkes automatisk ved f.eks. eksport fra tegneverktøy eller opplastning til filplassering. Noen krav vil måtte sjekkes geometrisk, som da må gjøres i programvare som er egnet for slike sjekker.
#
# I flere tilfeller vil noen tidlige valg påvirke tillate verdier og relevante egenskaper senere i sjekk. Dette er tilfellet for trapp. Et av de første valgene er for eksempel å definere trappens plassering. Dersom trappen er utendørs, men en selvstendig konstruksjon - trapp i et opparbeidet uteareal, vil ikke §12.14 gjelde som trappeveilederen under viser.
#
# ![Trapp som ikke er dekket av §12.14](../img/trapp_utenfor_1214.png)

# %%
# Vi sjekker ut en eksempel modell for hvordan trappene er definerte 

office_model = ifcopenshell.open("../ifc/Kontorbygg.ifc")
print("IFC versjon: ",office_model.schema)
# Finnes det noe trapper?
stairs = office_model.by_type("IfcStair")
stairs
# Out:
# IFC versjon:  IFC4
# [#20349=IfcStair('08IOf0mJAoJe$oH18qOkmJ',#30,'Trapp-',$,$,#19076,#20340,'08498A40-C132-B24E-8FF2-44123462EC13',.NOTDEFINED.),
#  #79422=IfcStair('2qd55$6WmHJR_BSiJGj5DM',#30,'Trapp-',$,$,#77875,#79413,'B49C517F-1A0C-114D-BF8B-72C4D0B45356',.NOTDEFINED.),
#  #152680=IfcStair('3dNLjnK91jHvXGwVKvu2Is',#30,'Trapp-',$,$,#149631,#152671,'E75D5B71-5090-6D47-9850-E9F539E024B6',.NOTDEFINED.),
#  #214021=IfcStair('0azxc4iRlmJg7AZCqgiw0g',#30,'Trapp-',$,$,#214010,#214018,'24F7B984-B1BB-F04E-A1CA-8CCD2AB3A02A',.NOTDEFINED.),
#  #551874=IfcStair('3sXj3gZo8VIhtbd9lcm038',#30,'Trapp-',$,$,#548811,#551865,'F686D0EA-8F22-1F4A-BDE5-9C9BE6C000C8',.NOTDEFINED.),
#  #696477=IfcStair('2KIKBwHtKgJgAZNc_NDoDE',#30,'Trapp-',$,$,#696466,#696474,'944942FA-4775-2A4E-A2A3-5E6F9737234E',.NOTDEFINED.),
#  #998113=IfcStair('1EIY6iurnxIQo8YzmCgHwO',#30,'Trapp-',$,$,#998102,#998110,'4E4A21AC-E35C-7B49-AC88-8BDC0CA91E98',.NOTDEFINED.)]

# %% [markdown]
# # IfcStair kan være komponert av underelementer
#
# ![IfcStair IsDecomposedBy](../img/IfcStairElements.png)

# %%
# Hvordan er de satt sammen? 
for stair in stairs:
    print(stair.IsDecomposedBy)
# Out:
# ()
# ()
# ()
# ()
# ()
# ()
# ()

# %%
# Hvilke egenskaper finnes? 
for stair in stairs:
    print(ifcopenshell.util.element.get_psets(stair))
# Out:
# {'Pset_ConcreteElementGeneral': {'FireRating': '', 'id': 20355}, 'Pset_StairCommon': {'NumberOfRiser': 18.0, 'NumberOfTreads': 18.0, 'RiserHeight': 172.666666667, 'RequiredHeadroom': 2200.0, 'HandicapAccessible': False, 'FireRating': '', 'FireExit': False, 'IsExternal': False, 'id': 20370}, 'Pset_FireRatingProperties': {'FireResistanceRating': '', 'IsCombustible': False, 'id': 20385}}
# {'Pset_ConcreteElementGeneral': {'FireRating': '', 'id': 79428}, 'Pset_StairCommon': {'NumberOfRiser': 22.0, 'NumberOfTreads': 22.0, 'RiserHeight': 172.727272727, 'RequiredHeadroom': 2200.0, 'HandicapAccessible': False, 'FireRating': '', 'FireExit': False, 'IsExternal': False, 'id': 79443}, 'Pset_FireRatingProperties': {'FireResistanceRating': '', 'IsCombustible': False, 'id': 79458}}
# {'Pset_ConcreteElementGeneral': {'FireRating': '', 'id': 152686}, 'Pset_StairCommon': {'NumberOfRiser': 23.0, 'NumberOfTreads': 22.0, 'RiserHeight': 165.217391304, 'RequiredHeadroom': 2200.0, 'HandicapAccessible': False, 'FireRating': '', 'FireExit': False, 'IsExternal': False, 'id': 152701}, 'Pset_FireRatingProperties': {'FireResistanceRating': '', 'IsCombustible': False, 'id': 152716}}
# {'Pset_ConcreteElementGeneral': {'FireRating': '', 'id': 214027}, 'Pset_StairCommon': {'NumberOfRiser': 22.0, 'NumberOfTreads': 22.0, 'RiserHeight': 172.727272727, 'RequiredHeadroom': 2200.0, 'HandicapAccessible': False, 'FireRating': '', 'FireExit': False, 'IsExternal': False, 'id': 214042}, 'Pset_FireRatingProperties': {'FireResistanceRating': '', 'IsCombustible': False, 'id': 214057}}
# {'Pset_ConcreteElementGeneral': {'FireRating': '', 'id': 551880}, 'Pset_StairCommon': {'NumberOfRiser': 23.0, 'NumberOfTreads': 22.0, 'RiserHeight': 165.217391304, 'RequiredHeadroom': 2200.0, 'HandicapAccessible': False, 'FireRating': '', 'FireExit': False, 'IsExternal': False, 'id': 551895}, 'Pset_FireRatingProperties': {'FireResistanceRating': '', 'IsCombustible': False, 'id': 551910}}
# {'Pset_ConcreteElementGeneral': {'FireRating': '', 'id': 696483}, 'Pset_StairCommon': {'NumberOfRiser': 22.0, 'NumberOfTreads': 22.0, 'RiserHeight': 172.727272727, 'RequiredHeadroom': 2200.0, 'HandicapAccessible': False, 'FireRating': '', 'FireExit': False, 'IsExternal': False, 'id': 696498}, 'Pset_FireRatingProperties': {'FireResistanceRating': '', 'IsCombustible': False, 'id': 696513}}
# {'Pset_ConcreteElementGeneral': {'FireRating': '', 'id': 998119}, 'Pset_StairCommon': {'NumberOfRiser': 23.0, 'NumberOfTreads': 22.0, 'RiserHeight': 165.217391304, 'RequiredHeadroom': 2200.0, 'HandicapAccessible': False, 'FireRating': '', 'FireExit': False, 'IsExternal': False, 'id': 998134}, 'Pset_FireRatingProperties': {'FireResistanceRating': '', 'IsCombustible': False, 'id': 998149}}

# %%
# Railings er ikke del av IfcStairs i denne modellen, men finnes de på egenhånd?
railings = office_model.by_type("IfcRailing")
railings
# Out:
# [#36495=IfcRailing('2j418R_q_tH8vvMa95KyJB',#30,'Rekkverk-',$,$,#34350,#36486,'AD10121B-FB4F-B744-8E79-5A424553C4CB',.NOTDEFINED.),
#  #40607=IfcRailing('2sCQAFiQWjJwVZlpLzF9ZU',#30,'Rekkverk-',$,$,#36556,#40598,'B631A28F-B1A8-2D4F-A7E3-BF357D3C98DE',.NOTDEFINED.),
#  #42807=IfcRailing('0BPxNS_DXQG9JHTnZHcEyk',#30,'Rekkverk-',$,$,#40664,#42798,'0B67B5DC-F8D8-5A40-94D1-7718D198EF2E',.NOTDEFINED.),
#  #45822=IfcRailing('3lfWfM09ZNJB6E3xk6YQjR',#30,'Rekkverk-',$,$,#42864,#45813,'EFA60A56-0098-D74C-B18E-0FBB8689AB5B',.NOTDEFINED.),
#  #54571=IfcRailing('3RC$LTIllqJvyIpmV8tTkd',#30,'Rekkverk-',$,$,#45879,#54562,'DB33F55D-4AFB-F44F-9F12-CF07C8DDDBA7',.NOTDEFINED.),
#  #58252=IfcRailing('0_ZgxVHNRpG87H6tDxZJ_$',#30,'Rekkverk-',$,$,#54628,#58243,'3E8EAEDF-4576-F340-81D1-1B737B8D3FBF',.NOTDEFINED.),
#  #61135=IfcRailing('25fYpE9XeUGgElJRj6ESyI',#30,'Rekkverk-',$,$,#58309,#61126,'85A62CCE-261A-1E42-A3AF-4DBB4639CF12',.NOTDEFINED.),
#  #65249=IfcRailing('2XEQlSzl$mHAzOrV8_xdQg',#30,'Rekkverk-',$,$,#61192,#65240,'A139ABDC-F6FF-F044-AF58-D5F23EEE76AA',.NOTDEFINED.),
#  #67373=IfcRailing('1n_S7yUziiI8tsoVO6gxIp',#30,'Rekkverk-',$,$,#65306,#67364,'71F9C1FC-7BDB-2C48-8DF6-C9F606ABB4B3',.NOTDEFINED.),
#  #69078=IfcRailing('2hw5rhBiptIBpaN9G3ngXj',#30,'Rekkverk-',$,$,#67430,#69069,'ABE85D6B-2ECC-F748-BCE4-5C9403C6A86D',.NOTDEFINED.),
#  #72682=IfcRailing('08pPrcU4Q0HvE5NB3GSUYP',#30,'Rekkverk-',$,$,#69135,#72673,'08CD9D66-7846-8047-9385-5CB0D071E899',.NOTDEFINED.),
#  #75694=IfcRailing('0_hGjY711sGP_FM84OY_tN',#30,'Rekkverk-',$,$,#73589,#75685,'3EAD0B62-1C10-7641-9F8F-5881188BEDD7',.NOTDEFINED.),
#  #77818=IfcRailing('2xRAwVhcyVGR$xLLSjh1YC',#30,'Rekkverk-',$,$,#75751,#77809,'BB6CAE9F-AE6F-1F41-BFFB-55572DAC188C',.NOTDEFINED.),
#  #667415=IfcRailing('3XyzxovZdnHg3HOTlDgpH6',#30,'Rekkverk-',$,$,#664546,#667406,'E1F3DEF2-E639-F146-A0D1-61DBCDAB3446',.NOTDEFINED.),
#  #668818=IfcRailing('0W0K5YTm1TGAjZGfs6WLpF',#30,'Rekkverk-',$,$,#667472,#668809,'20014162-7700-5D40-AB63-429D86815CCF',.NOTDEFINED.),
#  #672747=IfcRailing('3hT3eSRmrGGglG$OHWBvw8',#30,'Rekkverk-',$,$,#668875,#672738,'EB743A1C-6F0D-5042-ABD0-FD84602F9E88',.NOTDEFINED.),
#  #673957=IfcRailing('131Aung_Q3GBcEu_J9WDIG',#30,'Rekkverk-',$,$,#672804,#673948,'4304AE31-ABE6-8340-B98E-E3E4C980D490',.NOTDEFINED.),
#  #679940=IfcRailing('2ykSvbE3H7JPBb71VJSBmU',#30,'Rekkverk-',$,$,#674014,#679931,'BCB9CE65-3834-474D-92E5-1C17D370BC1E',.NOTDEFINED.),
#  #681645=IfcRailing('3uSwsLsXRHGOBleHWcrMQE',#30,'Rekkverk-',$,$,#679997,#681636,'F873AD95-DA16-D141-82EF-A11826D5668E',.NOTDEFINED.),
#  #687508=IfcRailing('2kN3AlK4YnHQZXmnwamuJa',#30,'Rekkverk-',$,$,#681702,#687499,'AE5C32AF-5048-B145-A8E1-C31EA4C384E4',.NOTDEFINED.),
#  #694318=IfcRailing('2ZwNfceUfVHPP23s16CR3s',#30,'Rekkverk-',$,$,#688635,#694309,'A3E97A66-A1EA-5F45-9642-0F604631B0F6',.NOTDEFINED.),
#  #696409=IfcRailing('1Dc4DPeZzyGwaORJz4ROG2',#30,'Rekkverk-',$,$,#694375,#696400,'4D984359-A23F-7C43-A918-6D3F446D8402',.NOTDEFINED.),
#  #1086742=IfcRailing('1NVACoybx8GhXXOYdNOBTA',#30,'Rekkverk-',$,$,#1077646,#1086733,'577CA332-F25E-C842-B861-6229D760B74A',.NOTDEFINED.),
#  #1283114=IfcRailing('3H3h6LPpC0H87WvkPnMmZ9',#30,'Rekkverk-',$,$,#1281781,#1283105,'D10EB195-6733-0044-81E0-E6E6715B08C9',.NOTDEFINED.)]

# %%
# Hvilke egenskaper finnes? 
for railing in railings:
    print(ifcopenshell.util.element.get_psets(railing))
# Out:
# {'Pset_PrecastConcreteElementGeneral': {'SerialNumber': '', 'id': 36501}, 'AC_Pset_Dimension': {'Height': '1\xa0000', 'Length': '3\xa0542', 'id': 36510}, 'Pset_ManufacturerOccurrence': {'BarCode': '', 'SerialNumber': '', 'id': 36519}, 'Pset_ManufacturerTypeInformation': {'ModelLabel': '', 'Manufacturer': '', 'ProductionYear': 'DD/MM/ÅÅÅÅ', 'id': 36529}, 'Pset_RailingCommon': {'IsExternal': True, 'id': 36538}}
# {'Pset_PrecastConcreteElementGeneral': {'SerialNumber': '', 'id': 40613}, 'AC_Pset_Dimension': {'Height': '1\xa0000', 'Length': '4\xa0694', 'id': 40622}, 'Pset_ManufacturerOccurrence': {'BarCode': '', 'SerialNumber': '', 'id': 40631}, 'Pset_ManufacturerTypeInformation': {'ModelLabel': '', 'Manufacturer': '', 'ProductionYear': 'DD/MM/ÅÅÅÅ', 'id': 40641}, 'Pset_RailingCommon': {'IsExternal': True, 'id': 40650}}
# {'Pset_PrecastConcreteElementGeneral': {'SerialNumber': '', 'id': 42813}, 'AC_Pset_Dimension': {'Height': '1\xa0000', 'Length': '3\xa0542', 'id': 42822}, 'Pset_ManufacturerOccurrence': {'BarCode': '', 'SerialNumber': '', 'id': 42831}, 'Pset_ManufacturerTypeInformation': {'ModelLabel': '', 'Manufacturer': '', 'ProductionYear': 'DD/MM/ÅÅÅÅ', 'id': 42841}, 'Pset_RailingCommon': {'IsExternal': True, 'id': 42850}}
# {'Pset_PrecastConcreteElementGeneral': {'SerialNumber': '', 'id': 45828}, 'AC_Pset_Dimension': {'Height': '1\xa0000', 'Length': '4\xa0125', 'id': 45837}, 'Pset_ManufacturerOccurrence': {'BarCode': '', 'SerialNumber': '', 'id': 45846}, 'Pset_ManufacturerTypeInformation': {'ModelLabel': '', 'Manufacturer': '', 'ProductionYear': 'DD/MM/ÅÅÅÅ', 'id': 45856}, 'Pset_RailingCommon': {'IsExternal': True, 'id': 45865}}
# {'Pset_PrecastConcreteElementGeneral': {'SerialNumber': '', 'id': 54577}, 'AC_Pset_Dimension': {'Height': '1\xa0000', 'Length': '12\xa0784', 'id': 54586}, 'Pset_ManufacturerOccurrence': {'BarCode': '', 'SerialNumber': '', 'id': 54595}, 'Pset_ManufacturerTypeInformation': {'ModelLabel': '', 'Manufacturer': '', 'ProductionYear': 'DD/MM/ÅÅÅÅ', 'id': 54605}, 'Pset_RailingCommon': {'IsExternal': True, 'id': 54614}}
# {'Pset_PrecastConcreteElementGeneral': {'SerialNumber': '', 'id': 58258}, 'AC_Pset_Dimension': {'Height': '1\xa0000', 'Length': '5\xa0362', 'id': 58267}, 'Pset_ManufacturerOccurrence': {'BarCode': '', 'SerialNumber': '', 'id': 58276}, 'Pset_ManufacturerTypeInformation': {'ModelLabel': '', 'Manufacturer': '', 'ProductionYear': 'DD/MM/ÅÅÅÅ', 'id': 58286}, 'Pset_RailingCommon': {'IsExternal': True, 'id': 58295}}
# {'Pset_PrecastConcreteElementGeneral': {'SerialNumber': '', 'id': 61141}, 'AC_Pset_Dimension': {'Height': '1\xa0000', 'Length': '4\xa0096', 'id': 61150}, 'Pset_ManufacturerOccurrence': {'BarCode': '', 'SerialNumber': '', 'id': 61159}, 'Pset_ManufacturerTypeInformation': {'ModelLabel': '', 'Manufacturer': '', 'ProductionYear': 'DD/MM/ÅÅÅÅ', 'id': 61169}, 'Pset_RailingCommon': {'IsExternal': True, 'id': 61178}}
# {'Pset_PrecastConcreteElementGeneral': {'SerialNumber': '', 'id': 65255}, 'AC_Pset_Dimension': {'Height': '1\xa0000', 'Length': '4\xa0680', 'id': 65264}, 'Pset_ManufacturerOccurrence': {'BarCode': '', 'SerialNumber': '', 'id': 65273}, 'Pset_ManufacturerTypeInformation': {'ModelLabel': '', 'Manufacturer': '', 'ProductionYear': 'DD/MM/ÅÅÅÅ', 'id': 65283}, 'Pset_RailingCommon': {'IsExternal': True, 'id': 65292}}
# {'Pset_PrecastConcreteElementGeneral': {'SerialNumber': '', 'id': 67379}, 'AC_Pset_Dimension': {'Height': '1\xa0000', 'Length': '1\xa0881', 'id': 67388}, 'Pset_ManufacturerOccurrence': {'BarCode': '', 'SerialNumber': '', 'id': 67397}, 'Pset_ManufacturerTypeInformation': {'ModelLabel': '', 'Manufacturer': '', 'ProductionYear': 'DD/MM/ÅÅÅÅ', 'id': 67407}, 'Pset_RailingCommon': {'IsExternal': True, 'id': 67416}}
# {'Pset_PrecastConcreteElementGeneral': {'SerialNumber': '', 'id': 69084}, 'AC_Pset_Dimension': {'Height': '1\xa0000', 'Length': '1\xa0728', 'id': 69093}, 'Pset_ManufacturerOccurrence': {'BarCode': '', 'SerialNumber': '', 'id': 69102}, 'Pset_ManufacturerTypeInformation': {'ModelLabel': '', 'Manufacturer': '', 'ProductionYear': 'DD/MM/ÅÅÅÅ', 'id': 69112}, 'Pset_RailingCommon': {'IsExternal': False, 'id': 69121}}
# {'Pset_PrecastConcreteElementGeneral': {'SerialNumber': '', 'id': 72688}, 'AC_Pset_Dimension': {'Height': '1\xa0000', 'Length': '4\xa0619', 'id': 72697}, 'Pset_ManufacturerOccurrence': {'BarCode': '', 'SerialNumber': '', 'id': 72706}, 'Pset_ManufacturerTypeInformation': {'ModelLabel': '', 'Manufacturer': '', 'ProductionYear': 'DD/MM/ÅÅÅÅ', 'id': 72716}, 'Pset_RailingCommon': {'IsExternal': True, 'id': 72725}}
# {'Pset_PrecastConcreteElementGeneral': {'SerialNumber': '', 'id': 75700}, 'AC_Pset_Dimension': {'Height': '1\xa0000', 'Length': '2\xa0556', 'id': 75709}, 'Pset_ManufacturerOccurrence': {'BarCode': '', 'SerialNumber': '', 'id': 75718}, 'Pset_ManufacturerTypeInformation': {'ModelLabel': '', 'Manufacturer': '', 'ProductionYear': 'DD/MM/ÅÅÅÅ', 'id': 75728}, 'Pset_RailingCommon': {'IsExternal': False, 'id': 75737}}
# {'Pset_PrecastConcreteElementGeneral': {'SerialNumber': '', 'id': 77824}, 'AC_Pset_Dimension': {'Height': '1\xa0000', 'Length': '2\xa0082', 'id': 77833}, 'Pset_ManufacturerOccurrence': {'BarCode': '', 'SerialNumber': '', 'id': 77842}, 'Pset_ManufacturerTypeInformation': {'ModelLabel': '', 'Manufacturer': '', 'ProductionYear': 'DD/MM/ÅÅÅÅ', 'id': 77852}, 'Pset_RailingCommon': {'IsExternal': False, 'id': 77861}}
# {'Pset_PrecastConcreteElementGeneral': {'SerialNumber': '', 'id': 667421}, 'AC_Pset_Dimension': {'Height': '1\xa0000', 'Length': '3\xa0068', 'id': 667430}, 'Pset_ManufacturerOccurrence': {'BarCode': '', 'SerialNumber': '', 'id': 667439}, 'Pset_ManufacturerTypeInformation': {'ModelLabel': '', 'Manufacturer': '', 'ProductionYear': 'DD/MM/ÅÅÅÅ', 'id': 667449}, 'Pset_RailingCommon': {'IsExternal': False, 'id': 667458}}
# {'Pset_PrecastConcreteElementGeneral': {'SerialNumber': '', 'id': 668824}, 'AC_Pset_Dimension': {'Height': '1\xa0000', 'Length': '688', 'id': 668833}, 'Pset_ManufacturerOccurrence': {'BarCode': '', 'SerialNumber': '', 'id': 668842}, 'Pset_ManufacturerTypeInformation': {'ModelLabel': '', 'Manufacturer': '', 'ProductionYear': 'DD/MM/ÅÅÅÅ', 'id': 668852}, 'Pset_RailingCommon': {'IsExternal': False, 'id': 668861}}
# {'Pset_PrecastConcreteElementGeneral': {'SerialNumber': '', 'id': 672753}, 'AC_Pset_Dimension': {'Height': '1\xa0000', 'Length': '4\xa0467', 'id': 672762}, 'Pset_ManufacturerOccurrence': {'BarCode': '', 'SerialNumber': '', 'id': 672771}, 'Pset_ManufacturerTypeInformation': {'ModelLabel': '', 'Manufacturer': '', 'ProductionYear': 'DD/MM/ÅÅÅÅ', 'id': 672781}, 'Pset_RailingCommon': {'IsExternal': False, 'id': 672790}}
# {'Pset_PrecastConcreteElementGeneral': {'SerialNumber': '', 'id': 673963}, 'AC_Pset_Dimension': {'Height': '1\xa0000', 'Length': '1\xa0282', 'id': 673972}, 'Pset_ManufacturerOccurrence': {'BarCode': '', 'SerialNumber': '', 'id': 673981}, 'Pset_ManufacturerTypeInformation': {'ModelLabel': '', 'Manufacturer': '', 'ProductionYear': 'DD/MM/ÅÅÅÅ', 'id': 673991}, 'Pset_RailingCommon': {'IsExternal': False, 'id': 674000}}
# {'Pset_PrecastConcreteElementGeneral': {'SerialNumber': '', 'id': 679946}, 'AC_Pset_Dimension': {'Height': '1\xa0000', 'Length': '8\xa0941', 'id': 679955}, 'Pset_ManufacturerOccurrence': {'BarCode': '', 'SerialNumber': '', 'id': 679964}, 'Pset_ManufacturerTypeInformation': {'ModelLabel': '', 'Manufacturer': '', 'ProductionYear': 'DD/MM/ÅÅÅÅ', 'id': 679974}, 'Pset_RailingCommon': {'IsExternal': True, 'id': 679983}}
# {'Pset_PrecastConcreteElementGeneral': {'SerialNumber': '', 'id': 681651}, 'AC_Pset_Dimension': {'Height': '1\xa0000', 'Length': '2\xa0661', 'id': 681660}, 'Pset_ManufacturerOccurrence': {'BarCode': '', 'SerialNumber': '', 'id': 681669}, 'Pset_ManufacturerTypeInformation': {'ModelLabel': '', 'Manufacturer': '', 'ProductionYear': 'DD/MM/ÅÅÅÅ', 'id': 681679}, 'Pset_RailingCommon': {'IsExternal': False, 'id': 681688}}
# {'Pset_PrecastConcreteElementGeneral': {'SerialNumber': '', 'id': 687514}, 'AC_Pset_Dimension': {'Height': '1\xa0000', 'Length': '8\xa0941', 'id': 687523}, 'Pset_ManufacturerOccurrence': {'BarCode': '', 'SerialNumber': '', 'id': 687532}, 'Pset_ManufacturerTypeInformation': {'ModelLabel': '', 'Manufacturer': '', 'ProductionYear': 'DD/MM/ÅÅÅÅ', 'id': 687542}, 'Pset_RailingCommon': {'IsExternal': True, 'id': 687551}}
# {'Pset_PrecastConcreteElementGeneral': {'SerialNumber': '', 'id': 694324}, 'AC_Pset_Dimension': {'Height': '1\xa0000', 'Length': '7\xa0596', 'id': 694333}, 'Pset_ManufacturerOccurrence': {'BarCode': '', 'SerialNumber': '', 'id': 694342}, 'Pset_ManufacturerTypeInformation': {'ModelLabel': '', 'Manufacturer': '', 'ProductionYear': 'DD/MM/ÅÅÅÅ', 'id': 694352}, 'Pset_RailingCommon': {'IsExternal': False, 'id': 694361}}
# {'Pset_PrecastConcreteElementGeneral': {'SerialNumber': '', 'id': 696415}, 'AC_Pset_Dimension': {'Height': '1\xa0000', 'Length': '1\xa0984', 'id': 696424}, 'Pset_ManufacturerOccurrence': {'BarCode': '', 'SerialNumber': '', 'id': 696433}, 'Pset_ManufacturerTypeInformation': {'ModelLabel': '', 'Manufacturer': '', 'ProductionYear': 'DD/MM/ÅÅÅÅ', 'id': 696443}, 'Pset_RailingCommon': {'IsExternal': False, 'id': 696452}}
# {'Pset_PrecastConcreteElementGeneral': {'SerialNumber': '', 'id': 1086748}, 'AC_Pset_Dimension': {'Height': '1\xa0000', 'Length': '10\xa0678', 'id': 1086757}, 'Pset_ManufacturerOccurrence': {'BarCode': '', 'SerialNumber': '', 'id': 1086766}, 'Pset_ManufacturerTypeInformation': {'ModelLabel': '', 'Manufacturer': '', 'ProductionYear': 'DD/MM/ÅÅÅÅ', 'id': 1086776}, 'Pset_RailingCommon': {'IsExternal': False, 'id': 1086785}}
# {'Pset_PrecastConcreteElementGeneral': {'SerialNumber': '', 'id': 1283120}, 'AC_Pset_Dimension': {'Height': '1\xa0000', 'Length': '52\xa0170', 'id': 1283129}, 'Pset_ManufacturerOccurrence': {'BarCode': '', 'SerialNumber': '', 'id': 1283138}, 'Pset_ManufacturerTypeInformation': {'ModelLabel': '', 'Manufacturer': '', 'ProductionYear': 'DD/MM/ÅÅÅÅ', 'id': 1283148}, 'Pset_RailingCommon': {'IsExternal': False, 'id': 1283157}}

# %%
## Utility
import requests as req

def get_stair_type_dictionary():
    # Henter trappetypene fra API
    res = req.get("https://trappesjekk-api.ft.dibk.no/checklist-api").json()
    trappetyper = res["filters"]
    return trappetyper

def get_stair_type_enum():
    stair_type_dict = get_stair_type_dictionary()
    return list(stair_type_dict.keys())


def get_stair_type_requirement_text(stairtype : str):    
    res = req.get(f"https://trappesjekk-api.ft.dibk.no/checklist-api/{stairtype}")
    return res.json()

# %%
trappetyper = get_stair_type_enum()
# Out:
# ['hap', 'thpih', 'tiub', 'tib', 'tiib', 'srtb', 'hfb', 'srtib', 'tfb', 'tlsd']

# %%
# create new IDS 
# ref https://github.com/buildingSMART/IDS/blob/master/Documentation/ids-metadata.md 

TEK17_1208_ids = ids.Ids(
   title="§12-8. Entré og garderobe",
   author="sigve@skogli.digital",
   version="0.01",
   purpose= "Denne IDS filen er laget som en demonstrator for TEK og BIM for validering av §12-14. Trapp",
   description= "Som en del av digitalisering av TEK er denne IDS (Information Delivery Specification) filen laget med bakgrunn i å kunne validere at BIM modeller tilfredstiller §12-14. Trapp",
   milestone="MMI 500: As-Built")

# %% [markdown]
# ### Strukturerer etter trappetyper
#
# Se [sjekkliste for trappetypene her](https://trappesjekk.ft.dibk.no/checklist/)

# %%
# Sjekke at trappene i modellen har én av de tillate trappetypene.
# Out:
# {'hap': {'id': 'HAP',
#   'name': 'Hovedtrapp i arbeids - og publikumsbygning',
#   'description': 'Ut fra dine svar skal du prosjektere en hovedtrapp i arbeids- og publikumsbygning. Kravene er hentet fra TEK17 § 12-14, og forutsetter at du skal prosjektere etter preaksepterte ytelser.',
#   'orderNumber': 1,
#   'filters': {}},
#  'thpih': {'id': 'THPIH',
#   'name': 'Trapp i hovedløsning i arbeids- og publikumsbygning',
#   'description': 'Ut fra dine svar skal du prosjektere en trapp i hovedløsning i arbeids- og publikumsbygning. Kravene er hentet fra TEK17 § 12-14, og forutsetter at du skal prosjektere etter preaksepterte ytelser.',
#   'orderNumber': 2,
#   'filters': {}},
#  'tiub': {'id': 'TIUB',
#   'name': 'Trapp uten tilgjengelighetskrav',
#   'description': 'Ut fra dine svar skal du prosjektere en trapp uten krav til tilgjengelighet og universell utforming. Du har dermed enten en: 1) trapp i sekundære rømningsvei i arbeids- og publikumsbygninger, 2) rømningstrapp i en boligbygning som ikke har krav om tilgjengelighet eller 3) trapp i bygning som verken er bolig eller arbeids- og publikumsbygning (f eks ubetjent lager).\n\nKravene er hentet fra TEK17 § 12-14, og forutsetter at du skal prosjektere etter preaksepterte ytelser.',
#   'orderNumber': 3,
#   'filters': {}},
#  'tib': {'id': 'TIB',
#   'name': 'Trapp internt i boenhet - tilgjengelig bolig',
#   'description': 'Ut fra dine svar skal du enten prosjektere en trapp internt i boenhet eller en utvendig trapp som kun skal betjene én boenhet, hvor det er krav om tilgjengelighet. Kravene er hentet fra TEK17 § 12-14, og forutsetter at du skal prosjektere etter preaksepterte ytelser.',
#   'orderNumber': 4,
#   'filters': {}},
#  'tiib': {'id': 'TIIB',
#   'name': 'Trapp internt i boenhet - ikke-tilgjengelig bolig',
#   'description': 'Ut fra dine svar skal du enten prosjektere en trapp internt i boenhet eller en utvendig trapp som kun skal betjene én boenhet, hvor det ikke er krav om tilgjengelighet. Kravene er hentet fra TEK17 § 12-14, og forutsetter at du skal prosjektere etter preaksepterte ytelser.',
#   'orderNumber': 5,
#   'filters': {}},
#  'srtb': {'id': 'SRTB',
#   'name': 'Sekundær rømningstrapp - tilgjengelig bolig',
#   'description': 'Ut fra dine svar skal du prosjektere en sekundær rømningstrapp i en boligbygning hvor det er krav om minst én tilgjengelig boenhet. Kravene er hentet fra TEK17 § 12-14, og forutsetter at du skal prosjektere etter preaksepterte ytelser.',
#   'orderNumber': 6,
#   'filters': {}},
#  'hfb': {'id': 'HFB',
#   'name': 'Hovedtrapp flere boenheter - tilgjengelig bolig',
#   'description': 'Ut fra dine svar skal du prosjektere en hovedtrapp i en boligbygning hvor det krav om minst én tilgjengelig boenhet. Kravene er hentet fra TEK17 § 12-14, og forutsetter at du skal prosjektere etter preaksepterte ytelser.',
#   'orderNumber': 7,
#   'filters': {}},
#  'srtib': {'id': 'SRTIB',
#   'name': 'Hovedtrapp flere boenheter - ikke-tilgjengelig bolig',
#   'description': 'Ut fra dine svar skal du prosjektere en hovedtrapp i en boligbygning hvor det ikke er noen boenheter som har krav til tilgjengelig boenhet. Kravene er hentet fra TEK17 § 12-14, og forutsetter at du skal prosjektere etter preaksepterte ytelser.',
#   'orderNumber': 8,
#   'filters': {}},
#  'tfb': {'id': 'TFB',
#   'name': 'Trapp i fritidsbolig med én boenhet',
#   'description': 'Ut fra dine svar skal du prosjektere en trapp i fritidsbolig med én boenhet. Kravene er hentet fra TEK17 § 12-14, og forutsetter at du skal prosjektere etter preaksepterte ytelser.',
#   'orderNumber': 9,
#   'filters': {}},
#  'tlsd': {'id': 'TLSD',
#   'name': 'Trapp, leider eller stige til annet formål',
#   'description': 'Ut fra dine svar skal du prosjektere en trapp, leider eller stige til et ikke-måleverdig areal eller som kun skal brukes til byggverkets drift. Kravene er hentet fra TEK17 § 12-14, og forutsetter at du skal prosjektere etter preaksepterte ytelser.',
#   'orderNumber': 10,
#   'filters': {}}}

# %% [markdown]
# ##### 1) Spesifisere bygningstype

# %%
""" 

1) Spesifikasjon for sjekk av bygningstype

"""

bygningstype_spec = ids.Specification(
    name="Bygningstype",
    description= "Bygningstype må angi om det er en Tilgjengelig boenhet eller ikke",
    instructions="IfcBuilding skal brukes til å angi bygningstype iht. TEK17 definisjoner",
    minOccurs=1,
    ifcVersion="IFC4"
)
bygningstype_spec.applicability.append(
    ids.Entity(
        name = "IfcBuilding"
    )
)

bygningstype_spec.requirements.append(
    ids.Attribute(
        name = "LongName",
        value = ids.Restriction(
            options={"enumeration":[
                "Tilgjengelig Bolig",
                "Tilgjengelig Boenhet"
                ]
            }
        )
    )
)
bygningstype_spec.requirements.append(
    ids.Property(
        propertySet="Pset_BuildingCommon",
        name ="OccupancyType",
        value= "Tilgjengelig boenhet",
        datatype = "IfcLabel",
        uri="https://www.dibk.no/regelverk/byggteknisk-forskrift-tek17/12/i/innledning2#:~:text=personer%20i%20rullestol.-,Tilgjengelig%20boenhet,-Boenhet%20der%3A",
        instructions="For å sjelle opp mot §12-8. Entré og garderobe i TEK17 må OccupancyType være deklarert som Tilgjengelig boenhet"
    )
)
TEK17_1208_ids.specifications.append(bygningstype_spec)

# %% [markdown]
# ##### 2) Spesifisere krav til område for Entré / Inngang / Inngagsplan
#
# [Tilgjengelig boenhet](https://www.dibk.no/regelverk/byggteknisk-forskrift-tek17/12/i/innledning2#:~:text=personer%20i%20rullestol.-,Tilgjengelig%20boenhet,-Boenhet%20der%3A)
# Boenhet der:
#
# Alle hovedfunksjoner finnes på inngangsplanet, og
# Inngangsplanet er tilgjengelig for personer med nedsatt bevegelighet.
#
# Det må følgelig defineres et romlig område av typen "Inngangsplan", iht.
#
# [Inngangsplan](https://www.dibk.no/regelverk/byggteknisk-forskrift-tek17/12/i/innledning2#:~:text=med%20nedsatt%20bevegelighet.-,Inngangsplan,-Bygningens%20inngangsplan%20er)
# * Bygningens inngangsplan er det planet der bygningens hovedinngang er plassert. En bygning kan ha flere hovedinnganger.
# * Boenhetens inngangsplan er det planet hvor boenhetens inngangsdør er plassert.
# * Øvrige plan er de plan som har en høydeforskjell på mer enn 1,2 meter fra inngangsplanet. Er høydeforskjellen inntil 1,2 meter er det fortsatt inngangsplan.

# %%
""" 

2)a Spesifikasjon for sjekk av Inngangsplan

"""

inngangsplan_spec = ids.Specification(
    name="Inngangsplan",
    description= "Inngangsplan må være definert og romme alle hovedfunksjoner, samt være der bygningsens hovedinngang er plassert",
    instructions="Det skal eksistere minimum ett objekt til å definere Inngangsplanet i modellen iht TEK17",
    minOccurs=1,
    ifcVersion="IFC4"
)

# Vurdere å legge inn alternativ oppfyllelse, ved bruk av Rom med classe 511 Adkomst. 
inngangsplan_spec.applicability.append(
    ids.Entity(
        name = "IfcSpatialZone"
    )
)

inngangsplan_spec.applicability.append(
    ids.Attribute(
        name = "LongName", 
        value= ids.Restriction(
            options={"enumeration":[
                "Inngangsplan",
                "Entré",
                "Inngang",
                "511 Adkomstrom"
                ]
            }
        )
    )
)
# Må ha plassering for å kunne sjekke 1.2 m kravet ift. andre plan. 
inngangsplan_spec.requirements.append(
    ids.Attribute(
        name = "ObjectPlacement",
        instructions="Inngangsplanet må ha en definert plassering, slik at man kan stadfeste høyde til andre plan og objekter i modell"
    )
)

# Kreve at de oppgir type iht. TEK17 ordbok / typekatalog
inngangsplan_spec.requirements.append(
    ids.Attribute(
        name = "PredefinedType",
        value = ".USERDEFINED",
        instructions="Inngangsplanet må ha definert typebetegnelse iht. TEK 17"
    )
)
# Kreve at de oppgir type iht. TEK17 ordbok / typekatalog
inngangsplan_spec.requirements.append(
    ids.Attribute(
        name = "ObjectType",
        value= ids.Restriction(
            options={"enumeration":[
                "Inngangsplan",
                "Entré",
                "Inngang",
                "511 Adkomstrom"
                ]
            }
        ),
        instructions="Inngangsplanet må ha definert typebetegnelse iht. TEK 17"
    )
)
TEK17_1208_ids.specifications.append(inngangsplan_spec)

# %%
""" 

2)b Spesifikasjon for sjekk av dør inne i inngangsplan

"""
# Må være inne i IfcSpatialStructure
# Operasjon 
# Slagareal 
# Slagretning 

dor_inngangsplan_spec = ids.Specification(
    name="Inngangsplan - dører",
    description= "Inngangsplanet for Tilgjengelig boenhet skal ha dører med terskelfrihet og trinnfrihet",
    instructions="Det eksisterer dørobjekter som har oppgitt slagareal, slagretning og deklarering av tilgjengelighet for funksjonshemmede",
    minOccurs=1,
    ifcVersion="IFC4"
)
""" APPLICABILITY """
# Vurdere å legge inn alternativ oppfyllelse
dor_inngangsplan_spec.applicability.append(
    ids.Entity(
        name = "IfcDoor"
        )
    )


""" REQUIREMENTS """
# Objekt som selv er innenfor et annet IfcSpatialObject (av egendefinert type)
## NB: Sjekker bare dører som er innenfor "Inngangsplan"
dor_inngangsplan_spec.requirements.append(
    ids.PartOf(
        entity="IfcSpatialZone",
        relation="IFCRELCONTAINEDINSPATIALSTRUCTURE"
    )
)

dor_inngangsplan_spec.requirements.append(
    ids.Attribute(
        name = "ObjectPlacement",
        instructions="Dørobjektet må ha en definert plassering"
    )
)

dor_inngangsplan_spec.requirements.append(
    ids.Attribute(
        name = "Representation",
        instructions="Dørobjektet må ha en definert og representativ geometri"
    )
)

# Kreve at de oppgir type iht. TEK17 ordbok / typekatalog
dor_inngangsplan_spec.requirements.append(
    ids.Property(
        propertySet="Pset_DoorCommon",
        name = "HandicapAccessible",
        value = "TRUE",
        datatype = "IfcBoolean",
        minOccurs=1,
        instructions="Døren må være tilgjengelig for funksjonshemmede"
    )
)
# Kreve at de oppgir type iht. TEK17 ordbok / typekatalog
dor_inngangsplan_spec.requirements.append(
    ids.Attribute(
        name = "OverallWidth",
        value = ids.Restriction(
            options={ 
                "minInclusive": 0.9
            }
        ),
        instructions="Dørbredden må være definert og minimum 0.9 m"
    )
)
TEK17_1208_ids.specifications.append(dor_inngangsplan_spec)

# %% [markdown]
# #### 3) Spesifikasjon av Fri passasje inne i Inngangsplan
#
# Inngangsplanet skal sikre fri passasje på minimum 0.9 m.

# %%
""" 

3) Spesifikasjon for sjekk av Fri passasje

"""

fri_passasje_spec = ids.Specification(
    name="Fri passasje",
    description= "Inngangsplanet for Tilgjengelig boenhet skal ha fri passasje på minimum 0.9 m",
    instructions="Det skal eksistere ett objekt i inngangsplanet som angir fri passasje på minimum 0.9 m",
    minOccurs=1,
    ifcVersion="IFC4"
)
""" APPLICABILITY """
# Vurdere å legge inn alternativ oppfyllelse, ved bruk av Rom med classe 511 Adkomst. 
fri_passasje_spec.applicability.append(
    ids.Entity(
        name = "IfcSpatialZone"
        )
    )

fri_passasje_spec.applicability.append(
    ids.Attribute(
        name = "LongName", 
        value= "Fri passasje"
    )
)
""" REQUIREMENTS """
# Objekt som selv er innenfor et annet IfcSpatialObject (av egendefinert type)
fri_passasje_spec.requirements.append(
    ids.PartOf(
        entity="IfcSpatialZone", predefinedType=".USERDEFINED",
        relation="IFCRELCONTAINEDINSPATIALSTRUCTURE"
    )
)



fri_passasje_spec.requirements.append(
    ids.Attribute(
        name = "ObjectPlacement",
        instructions="Fri passasje objektet må ha en definert plassering"
    )
)

fri_passasje_spec.requirements.append(
    ids.Attribute(
        name = "Representation",
        instructions="Fri passasje objektet må ha en definert og representativ geometri"
    )
)

# Kreve at de oppgir type iht. TEK17 ordbok / typekatalog
fri_passasje_spec.requirements.append(
    ids.Property(
        propertySet="NODIBK_TEK17",
        name = "FreePassage",
        value = ids.Restriction(
            options={ 
                "minInclusive": 0.9
            }
        ),
        datatype = "IfcPositiveLengthMeasure",
        minOccurs=1,
        instructions="Fri passasje objektet må ha et en definert bredde på mer enn 0.9 m"
    )
)
# Kreve at de oppgir type iht. TEK17 ordbok / typekatalog
fri_passasje_spec.requirements.append(
    ids.Attribute(
        name = "PredefinedType",
        value = ".USERDEFINED",
        instructions="Fri passasje må ha definert typebetegnelse iht. TEK 17"
    )
)
# Kreve at de oppgir type iht. TEK17 ordbok / typekatalog
fri_passasje_spec.requirements.append(
    ids.Attribute(
        name = "ObjectType",
        value= "Fri passasje",
        instructions="Fri passasje må ha definert typebetegnelse iht. TEK 17"
    )
)
TEK17_1208_ids.specifications.append(fri_passasje_spec)

# %% [markdown]
# #### b)  plass til snuareal for rullestol utenfor dørens slagradius.
#
# Det må være etablert et objekt for å angi korrekt snuareal som kan sjekkes at ikke har geometrisk konflikt med dørenes slagradius i inngangsplanet.

# %%
""" 

3) Spesifikasjon for sjekk av snuareal

"""

snuareal_spec = ids.Specification(
    name="Snuareal",
    description= "Inngangsplanet for Tilgjengelig boenhet skal ha plass til snuareal for rullestol utenfor dørens slagradius",
    instructions="Det skal eksistere en snusirkel eller snurektangel i inngangsplanet som har geometri som kan sjekkes at ikke går i konflikt med dørens slagradius",
    minOccurs=1,
    ifcVersion="IFC4"
)
""" APPLICABILITY """
# Vurdere å legge inn alternativ oppfyllelse, ved bruk av Rom med classe 511 Adkomst. 
snuareal_spec.applicability.append(
    ids.Entity(
        name = "IfcSpatialZone"
        )
    )

snuareal_spec.applicability.append(
    ids.Attribute(
        name = "LongName", 
        value= ids.Restriction(
            options={"enumeration":[
                "Snusirkel",
                "Snurektangel"
                ]
            }
        ),
    )
)

""" REQUIREMENTS """

# Objekt som selv er innenfor et annet IfcSpatialObject (av egendefinert type)
snuareal_spec.requirements.append(
    ids.PartOf(
        entity="IfcSpatialZone", predefinedType=".USERDEFINED",
        relation="IFCRELCONTAINEDINSPATIALSTRUCTURE"
    )
)

snuareal_spec.requirements.append(
    ids.Attribute(
        name = "ObjectPlacement",
        instructions="Snuarealobjektet må ha en definert plassering"
    )
)

snuareal_spec.requirements.append(
    ids.Attribute(
        name = "Representation",
        instructions="Snuarealobjektet må ha en definert og representativ geometri"
    )
)

# Kreve at de oppgir type iht. TEK17 ordbok / typekatalog
snuareal_spec.requirements.append(
    ids.Property(
        propertySet="NODIBK_TEK17",
        name = "TurnDiameter",
        value = ids.Restriction(
            options={ 
                "minInclusive": 1.5
            }
        ),
        datatype = "IfcPositiveLengthMeasure",
        minOccurs=1,
        instructions="Snusirkel må ha et en definert diameter på mer enn 1.5 m"
    )
)
# Kreve at de oppgir type iht. TEK17 ordbok / typekatalog
snuareal_spec.requirements.append(
    ids.Property(
        propertySet="NODIBK_TEK17",
        name = "TurnWidth",
        value = ids.Restriction(
            options={ 
                "minInclusive": 1.3
            }
        ),
        datatype = "IfcPositiveLengthMeasure",
        minOccurs=1,
        instructions="Snurektangel må ha et en definert bredde på mer enn 1.3 m"
    )
)
# Kreve at de oppgir type iht. TEK17 ordbok / typekatalog
snuareal_spec.requirements.append(
    ids.Property(
        propertySet="NODIBK_TEK17",
        name = "TurnLength",
        value = ids.Restriction(
            options={ 
                "minInclusive": 1.8
            }
        ),
        datatype = "IfcPositiveLengthMeasure",
        minOccurs=1,
        instructions="Snurektangel må ha et en definert lengde på mer enn 1.8 m"
    )
)
# Kreve at de oppgir type iht. TEK17 ordbok / typekatalog
snuareal_spec.requirements.append(
    ids.Attribute(
        name = "PredefinedType",
        value = ".USERDEFINED",
        instructions="Snuareal må ha definert typebetegnelse iht. TEK 17"
    )
)
# Kreve at de oppgir type iht. TEK17 ordbok / typekatalog
snuareal_spec.requirements.append(
    ids.Attribute(
        name = "ObjectType",
        value= ids.Restriction(
            options={"enumeration":[
                "Snusirkel",
                "Snurektangel"
                ]
            }
        ),
        instructions="Snuareal må ha definert typebetegnelse iht. TEK 17"
    )
)
TEK17_1208_ids.specifications.append(snuareal_spec)

# %%
TEK17_1208_ids.to_xml("../ids/§12_08. Entré og garderobe.ids")
# Out:
# True

# %% [markdown]
# ## §12-10 Bod og oppbevaringsplass

# %%
# create new IDS 
# ref https://github.com/buildingSMART/IDS/blob/master/Documentation/ids-metadata.md 

TEK_ids = ids.Ids(
   title="TEK og BIM",
   author="sigve@mok-see.com",
   copyright="[mok-see] AS",
   version="0.01",
   purpose= "Denne IDS filen er laget som en demonstrator for TEK og BIM for validering av §12-10 Bod og oppbevaringsplass",
   description=   "Som en del av digitalisering av TEK er denne IDS (Information Delivery Specification) filen laget med bakgrunn i å kunne validere at BIM modeller tilfredstiller §12-10 Bod og oppbevaringsplass",
   milestone="MMI 500: As-Built")

# %% [markdown]
# ### Lage spesifikasjoner
#
# Spesifikasjonene som kreves i denne omgang er;
# 1. Boenheten skal ha tilstrekkelig og egnet plass for oppbevaring av klær
# 2. Boenheten skal ha tilstrekkelig og egnet plass for oppbevaring av mat

# %%
# Oppbevaring av klær spesifikasjon
oppbevaring_av_klar_spec = ids.Specification(
    name="§12-10 (1) Plass til oppbevaring av klær",
    description= "Boenheten skal ha tilstrekkelig og egnet plass for oppbevaring av klær",
    instructions="Produksjonsunderlag (BIM) må vise avsatt plass til oppbevaring av klær ved IfcSpatialZone eller IfcFurniture objekt.",
    minOccurs=1,
    ifcVersion="IFC4")

oppbevaring_av_klar_spec.applicability.append(ids.Entity(name="IfcSpatialZone"))
#oppbevaring_av_klar_spec.applicability.append(ids.Entity(name="IfcFurniture"))
oppbevaring_av_klar_spec.applicability.append(ids.Attribute(name="ObjectType",value="STORAGE_OF_CLOTHES"))
#oppbevaring_av_klar_spec.applicability.append(ids.Attribute(name="ObjectType",value="WARDROBE"))

name = ids.Attribute(
    name = "Name",
    instructions="Name må være angitt"
)
oppbevaring_av_klar_spec.requirements.append(name)

longName = ids.Attribute(
    name = "LongName",
    instructions="LongName må være angitt"
)
oppbevaring_av_klar_spec.requirements.append(longName)
# Legge til spesifikasjon i IDS
TEK_ids.specifications.append(oppbevaring_av_klar_spec)

# %%
# Oppbevaring av mat spesifikasjon
oppbevaring_av_torrmat_spec = ids.Specification(
    name="§12-10 (2) (1) Plass til oppbevaring av mat (Tørrmat)",
    description= "Boenheten skal ha tilstrekkelig og egnet plass for oppbevaring av tørrmat",
    instructions="Produksjonsunderlag (BIM) må vise avsatt plass til oppbevaring av tørrmat med riktig objekttype.",
    minOccurs=1,
    ifcVersion="IFC4")

## Virker som at det bare kan være en Entity i Applicability, men at man kan ha andre typer facetter som legges til.. 
oppbevaring_av_torrmat_spec.applicability.append(ids.Entity(name = "IfcSpatialZone"))
oppbevaring_av_torrmat_spec.applicability.append(ids.Attribute(
    name="ObjectType",value="STORAGE_DRY_FOOD"))

name = ids.Attribute(
    name = "Name",
    instructions="Name må være angitt"
)
oppbevaring_av_torrmat_spec.requirements.append(name)

longName = ids.Attribute(
    name = "LongName",
    instructions="LongName må være angitt"
)
oppbevaring_av_torrmat_spec.requirements.append(longName)

# Legge til spesifikasjon i IDS
TEK_ids.specifications.append(oppbevaring_av_torrmat_spec)

# %%
# Oppbevaring av mat spesifikasjon
oppbevaring_av_kjolevarer_spec = ids.Specification(
    name="§12-10 (2) (2) Plass til oppbevaring av mat (Kjølevarer)",
    description= "Boenheten skal ha tilstrekkelig og egnet plass for oppbevaring av kjølevarer",
    instructions="Produksjonsunderlag (BIM) må vise avsatt plass til oppbevaring av kjølevarer med riktig object type.",
    minOccurs=1,
    ifcVersion="IFC4")

oppbevaring_av_kjolevarer_spec.applicability.append(ids.Entity(name = "IfcElectricAppliance"))
#oppbevaring_av_kjolevarer_spec.applicability.append(ids.Attribute(
#    name="ObjectType",value="STORAGE_REFRIGERATED_GOODS"))
#oppbevaring_av_kjolevarer_spec.applicability.append(ids.Attribute(name="ObjectType",value="REFRIDGERATOR"))
oppbevaring_av_kjolevarer_spec.applicability.append(ids.Attribute(name="PredefinedType",value="FRIDGE_FREEZER"))

name = ids.Attribute(
    name = "Name"
)
oppbevaring_av_kjolevarer_spec.requirements.append(name)

longName = ids.Attribute(
    name = "LongName"
)
oppbevaring_av_kjolevarer_spec.requirements.append(longName)

# Legge til spesifikasjon i IDS
TEK_ids.specifications.append(oppbevaring_av_kjolevarer_spec)

# %%
# Skriv til fil
TEK_ids.to_xml("../ids/§12_10_TEK_IfcFuniture_and_IfcElectricAppliance_Error_LongName.ids")
# Out:
# True

# %%
file = ifcopenshell.open("../ifc/tek-bim.ifc")
tekids = ids.open("../ids/§12_10_TEK_IfcFuniture_and_IfcElectricAppliance_Error_LongName.ids")
tekids.validate(file)

# %%
reporter.Console(tekids).report()
# Out:
# TEK og BIM
# [FAIL] (0/1) *§12-10 (1) Plass til oppbevaring av klær
#     Applies to:
#         All IfcSpatialZone data
#         Data where the ObjectType is STORAGE_OF_CLOTHES
#     Requirements:
#         The Name shall be provided
#         The LongName shall be provided
#             The attribute value None is empty - #2911=IfcSpatialZone('0T9InqK9T2BvhcCuJN9byU',$,'Oppbevaring av klær',$,'STORAGE_OF_CLOTHES',#3745,#2917,$,.USERDEFINED.)
# [FAIL] (0/1) *§12-10 (2) (1) Plass til oppbevaring av mat (Tørrmat)
#     Applies to:
#         All IfcSpatialZone data
#         Data where the ObjectType is STORAGE_DRY_FOOD
#     Requirements:
#         The Name shall be provided
#         The LongName shall be provided
#             The attribute value None is empty - #2930=IfcSpatialZone('2DQ02zAnL4deegroDOcto7',$,'Oppbevaring av tørrmat',$,'STORAGE_DRY_FOOD',#3750,#2936,$,.USERDEFINED.)
# [FAIL] (0/1) *§12-10 (2) (2) Plass til oppbevaring av mat (Kjølevarer)
#     Applies to:
#         All IfcElectricAppliance data
#         Data where the PredefinedType is FRIDGE_FREEZER
#     Requirements:
#         The Name shall be provided
#         The LongName shall be provided
#             The attribute value None is empty - #3690=IfcElectricAppliance('2FT$pnRu53th7sS$pQ3Y1h',$,'Kjøleskap',$,$,#3719,#3708,$,.FRIDGE_FREEZER.)

# %%
# create new IDS 
# ref https://github.com/buildingSMART/IDS/blob/master/Documentation/ids-metadata.md 

TEK_ids = ids.Ids(
   title="TEK og BIM",
   author="sigve@mok-see.com",
   copyright="[mok-see] AS",
   version="0.01",
   purpose= "Denne IDS filen er laget som en demonstrator for TEK og BIM for validering av §12-10 Bod og oppbevaringsplass",
   description=   "Som en del av digitalisering av TEK er denne IDS (Information Delivery Specification) filen laget med bakgrunn i å kunne validere at BIM modeller tilfredstiller §12-10 Bod og oppbevaringsplass",
   milestone="MMI 500: As-Built")

# %% [markdown]
# ### Lage spesifikasjoner
#
# Spesifikasjonene som kreves i denne omgang er;
# 1. Boenheten skal ha tilstrekkelig og egnet plass for oppbevaring av klær
# 2. Boenheten skal ha tilstrekkelig og egnet plass for oppbevaring av mat

# %%
# Oppbevaring av klær spesifikasjon
oppbevaring_av_klar_spec = ids.Specification(
    name="§12-10 (1) Plass til oppbevaring av klær",
    description= "Boenheten skal ha tilstrekkelig og egnet plass for oppbevaring av klær",
    instructions="Produksjonsunderlag (BIM) må vise avsatt plass til oppbevaring av klær ved IfcSpatialZone eller IfcFurniture objekt.",
    minOccurs=1,
    ifcVersion="IFC4")

oppbevaring_av_klar_spec.applicability.append(ids.Entity(name="IfcSpatialZone"))
#oppbevaring_av_klar_spec.applicability.append(ids.Entity(name="IfcFurniture"))
oppbevaring_av_klar_spec.applicability.append(ids.Attribute(name="ObjectType",value="STORAGE_OF_CLOTHES"))
#oppbevaring_av_klar_spec.applicability.append(ids.Attribute(name="ObjectType",value="WARDROBE"))

name = ids.Attribute(
    name = "Name",
    instructions="Name må være angitt"
)
oppbevaring_av_klar_spec.requirements.append(name)

longName = ids.Attribute(
    name = "LongName",
    instructions="LongName må være angitt"
)
oppbevaring_av_klar_spec.requirements.append(longName)
# Legge til spesifikasjon i IDS
TEK_ids.specifications.append(oppbevaring_av_klar_spec)

# %%
# Oppbevaring av mat spesifikasjon
oppbevaring_av_torrmat_spec = ids.Specification(
    name="§12-10 (2) (1) Plass til oppbevaring av mat (Tørrmat)",
    description= "Boenheten skal ha tilstrekkelig og egnet plass for oppbevaring av tørrmat",
    instructions="Produksjonsunderlag (BIM) må vise avsatt plass til oppbevaring av tørrmat med riktig objekttype.",
    minOccurs=1,
    ifcVersion="IFC4")

## Virker som at det bare kan være en Entity i Applicability, men at man kan ha andre typer facetter som legges til.. 
oppbevaring_av_torrmat_spec.applicability.append(ids.Entity(name = "IfcSpatialZone"))
oppbevaring_av_torrmat_spec.applicability.append(ids.Attribute(
    name="ObjectType",value="STORAGE_DRY_FOOD"))

name = ids.Attribute(
    name = "Name",
    instructions="Name må være angitt"
)
oppbevaring_av_torrmat_spec.requirements.append(name)

longName = ids.Attribute(
    name = "LongName",
    instructions="LongName må være angitt"
)
oppbevaring_av_torrmat_spec.requirements.append(longName)

# Legge til spesifikasjon i IDS
TEK_ids.specifications.append(oppbevaring_av_torrmat_spec)

# %%
# Oppbevaring av mat spesifikasjon
oppbevaring_av_kjolevarer_spec = ids.Specification(
    name="§12-10 (2) (2) Plass til oppbevaring av mat (Kjølevarer)",
    description= "Boenheten skal ha tilstrekkelig og egnet plass for oppbevaring av kjølevarer",
    instructions="Produksjonsunderlag (BIM) må vise avsatt plass til oppbevaring av kjølevarer med riktig object type.",
    minOccurs=1,
    ifcVersion="IFC4")

oppbevaring_av_kjolevarer_spec.applicability.append(ids.Entity(name = "IfcElectricAppliance"))
#oppbevaring_av_kjolevarer_spec.applicability.append(ids.Attribute(
#    name="ObjectType",value="STORAGE_REFRIGERATED_GOODS"))
#oppbevaring_av_kjolevarer_spec.applicability.append(ids.Attribute(name="ObjectType",value="REFRIDGERATOR"))
oppbevaring_av_kjolevarer_spec.applicability.append(ids.Attribute(name="PredefinedType",value="FRIDGE_FREEZER"))

name = ids.Attribute(
    name = "Name"
)
oppbevaring_av_kjolevarer_spec.requirements.append(name)

longName = ids.Attribute(
    name = "LongName"
)
oppbevaring_av_kjolevarer_spec.requirements.append(longName)

# Legge til spesifikasjon i IDS
TEK_ids.specifications.append(oppbevaring_av_kjolevarer_spec)

# %%
# Skriv til fil
TEK_ids.to_xml("../ids/§12_10_TEK_IfcFuniture_and_IfcElectricAppliance_Error_LongName.ids")
# Out:
# True

# %%
file = ifcopenshell.open("../ifc/tek-bim.ifc")
tekids = ids.open("../ids/§12_10_TEK_IfcFuniture_and_IfcElectricAppliance_Error_LongName.ids")
tekids.validate(file)

# %%
reporter.Console(tekids).report()
# Out:
# TEK og BIM
# [FAIL] (0/1) *§12-10 (1) Plass til oppbevaring av klær
#     Applies to:
#         All IfcSpatialZone data
#         Data where the ObjectType is STORAGE_OF_CLOTHES
#     Requirements:
#         The Name shall be provided
#         The LongName shall be provided
#             The attribute value None is empty - #2911=IfcSpatialZone('0T9InqK9T2BvhcCuJN9byU',$,'Oppbevaring av klær',$,'STORAGE_OF_CLOTHES',#3745,#2917,$,.USERDEFINED.)
# [FAIL] (0/1) *§12-10 (2) (1) Plass til oppbevaring av mat (Tørrmat)
#     Applies to:
#         All IfcSpatialZone data
#         Data where the ObjectType is STORAGE_DRY_FOOD
#     Requirements:
#         The Name shall be provided
#         The LongName shall be provided
#             The attribute value None is empty - #2930=IfcSpatialZone('2DQ02zAnL4deegroDOcto7',$,'Oppbevaring av tørrmat',$,'STORAGE_DRY_FOOD',#3750,#2936,$,.USERDEFINED.)
# [FAIL] (0/1) *§12-10 (2) (2) Plass til oppbevaring av mat (Kjølevarer)
#     Applies to:
#         All IfcElectricAppliance data
#         Data where the PredefinedType is FRIDGE_FREEZER
#     Requirements:
#         The Name shall be provided
#         The LongName shall be provided
#             The attribute value None is empty - #3690=IfcElectricAppliance('2FT$pnRu53th7sS$pQ3Y1h',$,'Kjøleskap',$,$,#3719,#3708,$,.FRIDGE_FREEZER.)
